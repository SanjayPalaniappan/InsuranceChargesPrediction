# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the dataset
insurance_data=pd.read_csv('insurance_pre.csv')
insurance_data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Getting the column names of insurance dataset
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
#Converting categorical data into numerical data
ins_data_numerical=pd.get_dummies(insurance_data,drop_first=True)
ins_data_numerical
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Getting the column names of insurance dataset, after converting categorical data to numerical 
ins_data_numerical.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Storing input and output into separate variables
indep_ins_Data=ins_data_numerical[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep_ins_data=ins_data_numerical[['charges']]

# %%
#Splitting data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep_ins_Data,dep_ins_data,test_size=1/3,random_state=0)

# %%
#Applying standardization to bring data into same scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#Building a Grid search cross validated SVM model using train data
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
parameter_grid = {'kernel':['linear','rbf','poly','sigmoid'], 'C':[10,100,1000,5000,10000], 'gamma':['auto','scale']}
gridSearchSVMModel=GridSearchCV(SVR(),parameter_grid,refit=True,verbose=3,n_jobs=-1)
gridSearchSVMModel=gridSearchSVMModel.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\sanja\Anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Getting the best params from the grid and displaying the same
result=gridSearchSVMModel.cv_results_
print("The best parameter for which R_score value would be high is{}:".format(gridSearchSVMModel.best_params_))
# Out:
# The R_score value for best parameter {'C': 10000, 'gamma': 'scale', 'kernel': 'rbf'}:

# %%
#Creating a table and displaying the results
table=pd.DataFrame().from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.058139      0.006790         0.010044        0.002170      10
# 1        0.071015      0.007125         0.038555        0.006173      10
# 2        0.053311      0.003961         0.014534        0.003935      10
# 3        0.073461      0.003612         0.016748        0.002303      10
# 4        0.046600      0.005315         0.011232        0.002656      10
# 5        0.066873      0.011354         0.036138        0.001628      10
# 6        0.050716      0.006571         0.005725        0.005938      10
# 7        0.070332      0.005671         0.013450        0.003905      10
# 8        0.065141      0.011698         0.009242        0.001857     100
# 9        0.061826      0.005588         0.038931        0.006652     100
# 10       0.059557      0.007872         0.013389        0.002898     100
# 11       0.066452      0.006591         0.013768        0.003412     100
# 12       0.057239      0.006387         0.014201        0.004371     100
# 13       0.066023      0.005129         0.035248        0.001741     100
# 14       0.049880      0.003325         0.012681        0.004160     100
# 15       0.069381      0.008637         0.019672        0.005008     100
# 16       0.074150      0.009978         0.010957        0.002679    1000
# 17       0.078896      0.007007         0.036471        0.004035    1000
# 18       0.070260      0.007185         0.012410        0.005626    1000
# 19       0.079250      0.005589         0.012536        0.003795    1000
# 20       0.077352      0.002066         0.002544        0.002255    1000
# 21       0.078122      0.007884         0.035428        0.002699    1000
# 22       0.071788      0.006487         0.016406        0.006509    1000
# 23       0.078330      0.004522         0.012930        0.001390    1000
# 24       0.122801      0.013409         0.013064        0.007153    5000
# 25       0.102126      0.010989         0.033616        0.005228    5000
# 26       0.254959      0.107404         0.011778        0.001258    5000
# 27       0.073667      0.005401         0.011527        0.004264    5000
# 28       0.126291      0.015476         0.007574        0.006109    5000
# 29       0.092712      0.006703         0.037100        0.007673    5000
# 30       0.223521      0.032339         0.010873        0.002910    5000
# 31       0.079725      0.005919         0.018300        0.002569    5000
# 32       0.294813      0.273685         0.008644        0.003771   10000
# 33       0.143295      0.011177         0.034357        0.003123   10000
# 34       0.553622      0.233146         0.005718        0.005624   10000
# 35       0.074926      0.004568         0.014650        0.004387   10000
# 36       0.267760      0.263368         0.011620        0.002412   10000
# 37       0.136742      0.018539         0.027846        0.004172   10000
# 38       0.449683      0.216222         0.000798        0.001596   10000
# 39       0.071772      0.005149         0.012547        0.004905   10000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.387624
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.004176
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.047420
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.044787
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.387624
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.003956
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.043648
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043946
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.596232
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.303414
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.542212
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.492088
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.596232
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.304939
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.532310
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.491855
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.686126
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.731430
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.799185
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.232428
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.686126
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.732079
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.798212
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.248266
# 24   {'C': 5000, 'gamma': 'auto', 'kernel': 'linear'}           0.669814
# 25      {'C': 5000, 'gamma': 'auto', 'kernel': 'rbf'}           0.801749
# 26     {'C': 5000, 'gamma': 'auto', 'kernel': 'poly'}           0.803344
# 27  {'C': 5000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -5.949758
# 28  {'C': 5000, 'gamma': 'scale', 'kernel': 'linear'}           0.669814
# 29     {'C': 5000, 'gamma': 'scale', 'kernel': 'rbf'}           0.801823
# 30    {'C': 5000, 'gamma': 'scale', 'kernel': 'poly'}           0.803394
# 31  {'C': 5000, 'gamma': 'scale', 'kernel': 'sigmo...          -5.568496
# 32  {'C': 10000, 'gamma': 'auto', 'kernel': 'linear'}           0.669769
# 33     {'C': 10000, 'gamma': 'auto', 'kernel': 'rbf'}           0.803957
# 34    {'C': 10000, 'gamma': 'auto', 'kernel': 'poly'}           0.801434
# 35  {'C': 10000, 'gamma': 'auto', 'kernel': 'sigmo...         -26.780657
# 36  {'C': 10000, 'gamma': 'scale', 'kernel': 'line...           0.669769
# 37    {'C': 10000, 'gamma': 'scale', 'kernel': 'rbf'}           0.804126
# 38   {'C': 10000, 'gamma': 'scale', 'kernel': 'poly'}           0.801391
# 39  {'C': 10000, 'gamma': 'scale', 'kernel': 'sigm...         -18.439298
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.461268           0.288301           0.340540
# 1            0.022594          -0.118956          -0.082926
# 2            0.077536          -0.060527          -0.009476
# 3            0.081689          -0.072355          -0.027541
# 4            0.461268           0.288301           0.340540
# 5            0.022453          -0.119035          -0.082925
# 6            0.079780          -0.059229          -0.009498
# 7            0.082230          -0.072132          -0.027546
# 8            0.635776           0.566816           0.588799
# 9            0.319385           0.155546           0.208414
# 10           0.566743           0.471172           0.537557
# 11           0.545107           0.438714           0.468576
# 12           0.635776           0.566816           0.588799
# 13           0.318480           0.155033           0.208422
# 14           0.571466           0.474948           0.537506
# 15           0.544604           0.439299           0.468556
# 16           0.598398           0.586104           0.573860
