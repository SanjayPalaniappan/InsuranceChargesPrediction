# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loading the dataset
insurance_data=pd.read_csv('insurance_pre.csv')
insurance_data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Getting the column names of insurance dataset
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
#Converting categorical data into numerical data
ins_data_numerical=pd.get_dummies(insurance_data,drop_first=True)
ins_data_numerical
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Getting the column names of insurance dataset, after converting categorical data to numerical 
ins_data_numerical.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Storing input and output into separate variables
indep_ins_Data=ins_data_numerical[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep_ins_data=ins_data_numerical[['charges']]

# %%
#Splitting data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep_ins_Data,dep_ins_data,test_size=1/3,random_state=0)

# %%
#Applying standardization to bring data into same scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#Building a Grid search cross validated Decision tree model using train data
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
parameter_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 'max_features':['auto','sqrt','log2'], 'splitter':['best','random']}
gridSearch_DtModel=GridSearchCV(DecisionTreeRegressor(), parameter_grid, refit=True, verbose=3, n_jobs=-1)
gridSearch_DtModel=gridSearch_DtModel.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
#Getting the best params from the grid and displaying the same
result=gridSearch_DtModel.cv_results_
print("The best parameter for which R_score value would be high is{}:".format(gridSearch_DtModel.best_params_))
# Out:
# The best parameter for which R_score value would be high is{'criterion': 'squared_error', 'max_features': 'auto', 'splitter': 'best'}:

# %%
#Creating a table and displaying the results
table=pd.DataFrame().from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009104      0.001010         0.001603        0.003205
# 1        0.006141      0.003139         0.003215        0.003055
# 2        0.007190      0.005967         0.003600        0.004033
# 3        0.003589      0.001862         0.003679        0.001016
# 4        0.004851      0.001014         0.002666        0.001046
# 5        0.002937      0.000879         0.001268        0.001161
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.003125      0.006250         0.000000        0.000000
# 8        0.006249      0.007654         0.000000        0.000000
# 9        0.000000      0.000000         0.000000        0.000000
# 10       0.004412      0.005805         0.001287        0.001638
# 11       0.005492      0.006675         0.000784        0.001125
# 12       0.023079      0.007393         0.000000        0.000000
# 13       0.016059      0.004455         0.004642        0.006231
# 14       0.015301      0.000274         0.003394        0.004157
# 15       0.011256      0.006320         0.000000        0.000000
# 16       0.012656      0.007840         0.000000        0.000000
# 17       0.007951      0.006993         0.000000        0.000000
# 18       0.003145      0.006290         0.003203        0.003936
# 19       0.003128      0.006255         0.000000        0.000000
# 20       0.003145      0.006290         0.000000        0.000000
# 21       0.006330      0.005879         0.000000        0.000000
# 22       0.003145      0.006290         0.003128        0.006255
# 23       0.004628      0.006224         0.001702        0.003403
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.708347
# 1   {'criterion': 'squared_error', 'max_features':...           0.538085
# 2   {'criterion': 'squared_error', 'max_features':...           0.619703
# 3   {'criterion': 'squared_error', 'max_features':...           0.560363
# 4   {'criterion': 'squared_error', 'max_features':...           0.576994
# 5   {'criterion': 'squared_error', 'max_features':...           0.689232
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.692959
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.687227
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.582684
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.563502
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.710480
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.633296
# 12  {'criterion': 'absolute_error', 'max_features'...           0.624304
# 13  {'criterion': 'absolute_error', 'max_features'...           0.664939
# 14  {'criterion': 'absolute_error', 'max_features'...           0.512318
# 15  {'criterion': 'absolute_error', 'max_features'...           0.578684
# 16  {'criterion': 'absolute_error', 'max_features'...           0.648320
# 17  {'criterion': 'absolute_error', 'max_features'...           0.669470
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.573300
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.613021
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.269081
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.559931
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.545215
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.296706
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.510887           0.798292           0.633189
# 1            0.626312           0.634287           0.644144
# 2            0.555890           0.549744           0.626418
# 3            0.505091           0.689262           0.541072
# 4            0.572226           0.688197           0.572245
# 5            0.470440           0.604776           0.496421
# 6            0.490227           0.763978           0.609323
# 7            0.556639           0.688905           0.516765
# 8            0.571598           0.712563           0.583092
# 9            0.622233           0.662111           0.653209
# 10           0.624701           0.373785           0.519627
# 11           0.504702           0.635103           0.469377
# 12           0.557079           0.677600           0.596930
# 13           0.509673           0.698501           0.465619
# 14           0.484144           0.578461           0.622782
# 15           0.600824           0.716929           0.665454
# 16           0.547512           0.674610           0.575066
# 17           0.527673           0.653091           0.551882
# 18           0.541405           0.632580           0.607544
# 19           0.454628           0.691030           0.340206
# 20           0.567413           0.552892           0.528309
# 21           0.643873           0.610033           0.430002
# 22           0.402593           0.572388           0.623884
# 23           0.386522           0.428051           0.566689
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.647724         0.659688        0.094410                1
# 1            0.623242         0.613214        0.038255                7
# 2            0.701780         0.610707        0.055396                9
# 3            0.564641         0.572086        0.062247               18
# 4            0.663761         0.614684        0.050670                6
# 5            0.601773         0.572528        0.079661               17
# 6            0.668736         0.645044        0.091920                2
# 7            0.704147         0.630737        0.078030                3
# 8            0.614887         0.612965        0.051853                8
# 9            0.599745         0.620160        0.036009                4
# 10           0.428886         0.531496        0.123503               22
# 11           0.645067         0.577509        0.074815               16
# 12           0.639124         0.619007        0.040468                5
# 13           0.684309         0.604608        0.097096               12
# 14           0.602703         0.560081        0.053167               19
# 15           0.477255         0.607829        0.081451               11
# 16           0.606965         0.610495        0.046424               10
# 17           0.579472         0.596318        0.055758               14
# 18           0.644103         0.599786        0.037972               13
# 19           0.663161         0.552409        0.133975               20
# 20           0.583561         0.500251        0.117004               23
# 21           0.654269         0.579622        0.081730               15
# 22           0.562148         0.541246        0.074130               21
# 23           0.551017         0.445797        0.101728               24

# %%
#Getting the inputs from the user and predicting for future
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:30
# BMI:20
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=gridSearch_DtModel.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16085.1275]
